# %% [markdown]
# <a href="https://colab.research.google.com/github/t2wain/colab/blob/master/TN_Machine_Learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/t2wain/machine-learning.git
# !cp -r /content/machine-learning/tnmlearn/ /content/tnmlearn/
# !rm -rf /content/machine-learning/

# %%
# !rm -rf '/content/tnmlearn'

# %%
# !rm -rf '/content/17flowers'

# %%
from tnmlearn.examples import KerasCifar10
from tnmlearn.examples import KerasMnist
from tnmlearn.examples import LeNetMnist
from tnmlearn.examples import MiniVggNetCifar10
from tnmlearn.examples import Cifar10Monitor
from tnmlearn.examples import Cifar10Checkpoint
from tnmlearn.examples import ShallowNetAnimals

# %% [markdown]
# # Kaggle API

# %% [markdown]
# ## Configure API

# %%
# Run this cell and select the kaggle.json file downloaded
# from the Kaggle account settings page.
from google.colab import files
files.upload()

# %%
# Next, install the Kaggle API client.
# !pip install -q kaggle

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ## Download dogs-vs-cats

# %%
# List available datasets.
# !kaggle competitions download -c dogs-vs-cats

# %%
# !rm -rf '/content/dogcat'

# %%
from tnmlearn.datasets.dog_cat_dataset import unzip_datafile, split_dog_cat_image_files
from tnmlearn.other import paths

# %%
unzip_datafile('/content/train.zip', '/content/dogcat')

# %%
split_dog_cat_image_files('/content/dogcat/train')

# %%
list(paths.list_images('/content/dogcat'))

# %% [markdown]
# # Training Cifar10 dataset with a DNN

# %%
m = KerasCifar10()
m.getData()
m.build()
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#     airplane       0.66      0.64      0.65      1000
#   automobile       0.67      0.68      0.67      1000
#         bird       0.46      0.49      0.48      1000
#          cat       0.36      0.49      0.41      1000
#         deer       0.52      0.50      0.51      1000
#          dog       0.47      0.41      0.44      1000
#         frog       0.66      0.55      0.60      1000
#        horse       0.66      0.60      0.63      1000
#         ship       0.70      0.69      0.70      1000
#        truck       0.61      0.60      0.60      1000
#
#     accuracy                           0.57     10000
#    macro avg       0.58      0.57      0.57     10000
# weighted avg       0.58      0.57      0.57     10000

# %% [markdown]
# # Training Cifar10 dataset with MiniVggNet

# %%
m = MiniVggNetCifar10()
m.getData()
m.build()
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#     airplane       0.85      0.84      0.85      1000
#   automobile       0.93      0.90      0.91      1000
#         bird       0.81      0.71      0.75      1000
#          cat       0.67      0.69      0.68      1000
#         deer       0.74      0.85      0.79      1000
#          dog       0.78      0.73      0.75      1000
#         frog       0.83      0.90      0.87      1000
#        horse       0.91      0.85      0.88      1000
#         ship       0.91      0.90      0.91      1000
#        truck       0.86      0.90      0.88      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.83     10000
# weighted avg       0.83      0.83      0.83     10000

# %% [markdown]
# # Training MNIST dataset with LeNet

# %%
m = LeNetMnist()
m.getData()
m.build()
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      1733
#          1.0       0.99      0.99      0.99      1954
#          2.0       0.98      0.98      0.98      1752
#          3.0       0.99      0.97      0.98      1723
#          4.0       0.99      0.98      0.98      1711
#          5.0       0.98      0.98      0.98      1577
#          6.0       0.99      0.99      0.99      1689
#          7.0       0.99      0.97      0.98      1871
#          8.0       0.96      0.98      0.97      1771
#          9.0       0.95      0.98      0.97      1719
#
#     accuracy                           0.98     17500
#    macro avg       0.98      0.98      0.98     17500
# weighted avg       0.98      0.98      0.98     17500

# %% [markdown]
# # Training MNIST dataset with DNN

# %%
m = KerasMnist()
m.getData()
m.build()
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96      1747
#          1.0       0.95      0.96      0.96      1974
#          2.0       0.92      0.88      0.90      1786
#          3.0       0.90      0.89      0.90      1784
#          4.0       0.91      0.93      0.92      1693
#          5.0       0.87      0.85      0.86      1545
#          6.0       0.92      0.95      0.94      1734
#          7.0       0.93      0.93      0.93      1821
#          8.0       0.88      0.88      0.88      1697
#          9.0       0.89      0.90      0.89      1719
#
#     accuracy                           0.92     17500
#    macro avg       0.91      0.91      0.91     17500
# weighted avg       0.91      0.92      0.91     17500

# %% [markdown]
# # Training with Dog vs. Cat Dataset

# %%
m = ShallowNetAnimals('/content/dogcat/train')

# %%
m.getData()

# %%
m.build()

# %%
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#          cat       0.74      0.77      0.75      3141
#          dog       0.76      0.72      0.74      3109
#
#     accuracy                           0.75      6250
#    macro avg       0.75      0.75      0.75      6250
# weighted avg       0.75      0.75      0.75      6250

# %% [markdown]
# # Training with Flower-17 dataset

# %% [markdown]
# ## Download and extract data

# %%
# !wget 'http://www.robots.ox.ac.uk/~vgg/data/flowers/17/17flowers.tgz'

# %%
from tnmlearn.datasets.dog_cat_dataset import extract_file, split_17flowers
from tnmlearn.other import paths

extract_file('/content/17flowers.tgz', '/content/17flowers')
split_17flowers('/content/17flowers')

# %% [markdown]
# ## Training with data

# %%
from tnmlearn.examples import MiniVggNetFlowers17

# %%
m = MiniVggNetFlowers17('/content/17flowers')
m.getData()
m.build()
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#        dir_0       0.67      0.44      0.53        27
#        dir_1       0.44      0.55      0.49        20
#       dir_10       0.80      0.80      0.80        20
#       dir_11       0.57      0.57      0.57        23
#       dir_12       0.62      0.65      0.63        20
#       dir_13       0.48      0.61      0.54        23
#       dir_14       0.72      0.57      0.63        23
#       dir_15       0.82      0.74      0.78        19
#       dir_16       0.93      0.68      0.79        19
#        dir_2       0.43      0.41      0.42        22
#        dir_3       0.50      0.67      0.57        18
#        dir_4       0.45      0.56      0.50        16
#        dir_5       0.93      0.65      0.76        20
#        dir_6       0.86      0.67      0.75        18
#        dir_7       0.23      0.29      0.26        21
#        dir_8       0.62      0.67      0.65        15
# ...

# %% [markdown]
# # Training with augmented data

# %%
from tnmlearn.examples.minivggnet_flowers17_data_aug import MiniVggNetFlowers17DataAug

# %%
m = MiniVggNetFlowers17DataAug('/content/17flowers')

# %%
m.getData()
m.build()
m.fit()

# %%
m.plot()

# %%
m.evaluate()
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#        dir_0       0.55      0.44      0.49        27
#        dir_1       0.57      0.65      0.60        20
#       dir_10       0.79      0.95      0.86        20
#       dir_11       0.54      0.61      0.57        23
#       dir_12       0.60      0.60      0.60        20
#       dir_13       0.43      0.87      0.58        23
#       dir_14       0.89      0.70      0.78        23
#       dir_15       0.82      0.74      0.78        19
#       dir_16       0.94      0.79      0.86        19
#        dir_2       0.76      0.73      0.74        22
#        dir_3       0.83      0.83      0.83        18
#        dir_4       0.60      0.56      0.58        16
#        dir_5       0.88      0.75      0.81        20
#        dir_6       0.93      0.78      0.85        18
#        dir_7       0.50      0.29      0.36        21
#        dir_8       0.75      0.60      0.67        15
# ...
